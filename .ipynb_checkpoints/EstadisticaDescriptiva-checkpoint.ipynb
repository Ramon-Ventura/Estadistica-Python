# %% [markdown]
# # Preparando el Entorno de Trabajo

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#Para una distribucion normal definimos una variable para el valor central(central) y otra para la desviacion (desv)
central, desv = 10, 1

#Creamos una serie de diezmil valores aleatorios por medio de distribucion normal
aleatorios = np.random.normal(central, desv, 10000)

#Definimos nuestro dataframe
data = pd.DataFrame(
    {
        "valores":aleatorios.tolist()
    }
)

#Definimios nuestro histograma
count, bins, ignored = plt.hist(data["valores"], 30, density=True)

# Mostramos la curva de distribucion para verificar si es una distribucion normal
plt.plot(bins, 1/(desv * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - central)**2 / (2 * desv**2) ),linewidth=5, color='g')
plt.show()

# %% [markdown]
# # MEDIDAS DE CENTRALIZACION

# %% [markdown]
# Las medidas de centralizacion son valores "intermedios" que se situan alrededor del centro de la distribucion. Entre las medidas de centralizacion tenemos:
#
#     -Media
#     -Moda
#     -Mediana
#
# A continuacion se explicaran cada una de estas.

# %% [markdown]
# ## Media Aritmetica

# %% [markdown]
# ![mediagrafico.jpg](attachment:mediagrafico.jpg)

# %% [markdown]
# La media aritmética se define como la suma de N elementos dividida entre N. Se trata de una medida bastante conocida entre la gente, aunque tiene el inconveniente de que es muy susceptible a valores extremos.

# %% [markdown]
# La media aritmetica esta dada por la siguiente formula.

# %% [markdown]
# ![media.jpg](attachment:media.jpg)

# %% [markdown]
# Ejemplo en python

# %%
media = data.mean()
print(f'La media del conjunto de datos es de {media}')
# Out:
# La media del conjunto de datos es de valores    10.012708
# dtype: float64

# %% [markdown]
# El resultado debe ser muy aproximado al valor central que definimos anteriormente (osea 10).

# %% [markdown]
# ## Moda

# %% [markdown]
# ![modagrafico.jpg](attachment:modagrafico.jpg)

# %% [markdown]
# En estadística, la moda es el valor con mayor frecuencia en una de las distribuciones de datos. Esto va en forma de una columna cuando encontremos dos modas, es decir, dos datos que tengan la misma frecuencia absoluta máxima. Una distribución trimodal de los datos es en la que encontramos tres modas.

# %% [markdown]
# Ejemplo de moda en python.

# %%
moda = data['valores'].mode()
print(f'La moda del conjunto de datos es de {moda[0]}')
# Out:
# La moda del conjunto de datos es de 6.48457230639129

# %% [markdown]
# ## Mediana

# %% [markdown]
# ![medianagrafico.jpg](attachment:medianagrafico.jpg)

# %% [markdown]
# La mediana es el valor que ocupa el lugar central de todos los datos cuando éstos están ordenados de menor a mayor.

# %% [markdown]
# Ejemplo de mediana en python.

# %%
mediana = data['valores'].median()
print(f'La mediana del conjunto de datos es de {mediana}')
# Out:
# La mediana del conjunto de datos es de 10.021006279658563

# %% [markdown]
# ## Percentiles

# %% [markdown]
# ![percentiles.jpg](attachment:percentiles.jpg)

# %% [markdown]
# El concepto es igual al de mediana, salvo que aquí la división ya no es en el 50%. El 25% de las observaciones es menor que el primer cuartil. Los cuartiles abarcan el 25%, 50% y 75% de las observaciones. Los percentiles son una generalización con cualquier porcentaje.

# %% [markdown]
# Ejemplo en python.
# Que valor como minimo tiene el 10%(con mayores valores) del conjunto de valores?

# %%
percentil = data['valores'].quantile(0.9)
print(f'El valor como minimo que tiene un 10% con valores mayores  del conjunto de valores es de: {percentil}')
# Out:
# El valor como minimo que tiene un 10% con valores mayores  del conjunto de valores es de: 11.292035113021587

# %% [markdown]
# # MEDIDAS DE DISPERSION

# %% [markdown]
# Son parámetros estadísticos que indican como se alejan los datos respecto de la media aritmética. Sirven como indicador de la variabilidad de los datos. Las medidas de dispersión más utilizadas son el rango, la desviación estándar y la varianza.

# %% [markdown]
# ## Varianza

# %% [markdown]
# Es otro parámetro utilizado para medir la dispersión de los valores de una variable respecto a la media. Corresponde a la media aritmética de los cuadrados de las desviaciones respecto a la media. Su expresión matemática es:

# %% [markdown]
# ![varianzaformula.jpg](attachment:varianzaformula.jpg)

# %% [markdown]
# Ejemplo en python.

# %%
varianza = np.var(data['valores'])
print(f'La varianza entre el conjunto de valores es de: {varianza}')
# Out:
# La varianza entre el conjunto de valores es de: 1.0092769451495334

# %% [markdown]
# ## Desviacion Tipica

# %% [markdown]
# La desviación estándar mide el grado de disersión de los datos con respecto a la media, se denota como s para una muestra o como σ para la población.

# %% [markdown]
# La desviacion tipica esta dada por la siguiente formula:

# %% [markdown]
# ![desviaciontipijagrafico.jpg](attachment:desviaciontipijagrafico.jpg)

# %% [markdown]
# Ejemplo en python.

# %%
desviacion_tipica = np.std(data['valores'])
print(f'La desviacion tipica del conjunto de valores es de: {desviacion_tipica}')
# Out:
# La desviacion tipica del conjunto de valores es de: 1.0062925805230898

# %% [markdown]
# ## Coeficiente de Variacion

# %% [markdown]
# ![cvformula.jpg](attachment:cvformula.jpg)

# %% [markdown]
# Permite determinar la razón existente entre la desviación estándar (s) y la media. Se denota como CV. El coeficiente de variación permite decidir con mayor claridad sobre la dispersión de los datos.

# %%
coeficiente_variacion = (desviacion_tipica / data['valores'].mean())*100
print(f'El coeficiente de variacion es de: {coeficiente_variacion}%')
# Out:
# El coeficiente de variacion es de: 10.05652707981755%

# %% [markdown]
# # Momento de Orden "r" con respecto a la media

# %% [markdown]
# Se cumple que el momento de orden 0 con respecto a la media vale 1, el momento de orden 1 con respecto a la media vale 0 y el momento de orden 2 con respecto a la media es la varianza.

# %% [markdown]
# Formula para el momento de orden 0.

# %% [markdown]
# ![m0.svg](attachment:m0.svg)

# %% [markdown]
# Formula para el momento de orden 1.

# %% [markdown]
# ![m1.svg](attachment:m1.svg)

# %% [markdown]
# Formula para el momento de orden 2.

# %% [markdown]
# ![m3.svg](attachment:m3.svg)

# %% [markdown]
# Para los siguientes ejemplos definiremos un nuevo dataframe que contenga la frecuencia (ni) de cada uno de sus elementos como segunda columna.

# %%
data2 = pd.DataFrame(
    {
        "valores":data['valores'].tolist(),
        'fr':data['valores'].value_counts().tolist()
    }
)
data2
# Out:
#         valores  fr
# 0      7.713704   1
# 1      9.832378   1
# 2     11.653266   1
# 3     10.436910   1
# 4      9.612135   1
# ...         ...  ..
# 9995   8.813976   1
# 9996  10.201187   1
# 9997   9.387070   1
# 9998   8.849741   1
# 9999   9.134767   1
#
# [10000 rows x 2 columns]

# %% [markdown]
# Calculo del momento de orden 0.

# %%
s = 0
for x in range(0,10000):
    m = ((data2['valores'][x]-data2['valores'].mean())**0)*data2['fr'][x]
    s = s + m
print(s/10000)
# Out:
# 1.0

# %% [markdown]
# Verificamos que nuestro resultado sea igual 1 de acuerdo a la formula previamente planteada.

# %% [markdown]
# Calculo del momento de orden 1.

# %%
s = 0
for x in range(0,10000):
    m = ((data2['valores'][x]-data2['valores'].mean())**1)*data2['fr'][x]
    s = s + m
print(s/10000)
# Out:
# 7.780442956573097e-17

# %% [markdown]
# Verificamos que nuestro resultado sea igual o bastante aproximado al 0 de acuerdo a la formula previamente planteada.

# %% [markdown]
# Calculo del momento de orden 2.

# %%
s = 0
for x in range(0,10000):
    m = ((data2['valores'][x]-data2['valores'].mean())**2)*data2['fr'][x]
    s = s + m
print(s/10000)
# Out:
# 1.0092769451495345

# %% [markdown]
# Verificamos que el resultado sea igual a la varianza previamente calculada.

# %% [markdown]
# # Medias de asimetria

# %% [markdown]
# Es una medida de forma de una distribución que permite identificar y describir la manera como los datos tiende a reunirse de acuerdo con la frecuencia con que se hallen dentro de la distribución. Permite identificar las características de la distribución de datos sin necesidad de generar el gráfico.

# %% [markdown]
# ## Asimetria de Fisher

# %% [markdown]
# evalúa la proximidad de los datos a su media x. Cuanto mayor sea la suma ∑(xi–x)3, mayor será la asimetría. Sea el conjunto X=(x1, x2,…, xN), entonces la fórmula de la asimetría de Fisher es:

# %% [markdown]
# ![coeficiente-asimetria-fisher.jpg](attachment:coeficiente-asimetria-fisher.jpg)

# %% [markdown]
# Calculo de asimetria en python.

# %%
s = 0
for x in range(10000):
    numerador = (data2['valores'][x]-data2['valores'].mean())**3
    s = s + numerador
caf = s/(10000*(desviacion_tipica**3))
print(f'El coeficiente de asimetria es de: {caf}')
# Out:
# El coeficiente de asimetria es de: 0.002392567357488261

# %% [markdown]
# El resultado se puede comprobar calculando un momento de orden 3 y debe de ser igual o bastante aproximado.

# %%
s = 0
for x in range(0,10000):
    m = ((data2['valores'][x]-data2['valores'].mean())**3)*data2['fr'][x]
    s = s + m
print(s/10000)
# Out:
# 0.0024380184342730543

# %% [markdown]
# ## Curtosis

# %% [markdown]
#  La curtosis (o apuntamiento) es una medida de forma que mide cuán escarpada o achatada está una curva o distribución.
#
# Este coeficiente indica la cantidad de datos que hay cercanos a la media, de manera que a mayor grado de curtosis, más escarpada (o apuntada) será la forma de la curva.

# %% [markdown]
# ![curtosisg.jpg](attachment:curtosisg.jpg)

# %% [markdown]
# La curtosis se mide promediando la cuarta potencia de la diferencia entre cada elemento del conjunto y la media, dividido entre la desviación típica elevado también a la cuarta potencia. Sea el conjunto X=(x1, x2,…, xN), entonces el coeficiente de curtosis será:

# %% [markdown]
# ![curtosisf.jpg](attachment:curtosisf.jpg)

# %% [markdown]
# Calculo de curtosis en python.

# %%
s = 0
for x in range(10000):
    numerador = (data2['valores'][x]-data2['valores'].mean())**4
    s = s + numerador
curtosis = s/(10000*(desviacion_tipica**4))
print(f'La curtosis del conjunto de datos es de: {curtosis-3}')
# Out:
# La curtosis del conjunto de datos es de: -0.06278901576517848

# %% [markdown]
# # Muestreo aleatorio

# %% [markdown]
# ![muestreo.jpg](attachment:muestreo.jpg)

# %% [markdown]
# En la referencia estadística se conoce como muestreo a la técnica para la selección de una muestra a partir de una población estadística.
#
# Al elegir una muestra aleatoria se espera conseguir que sus propiedades sean extrapolables a la población. Este proceso permite ahorrar recursos, y a la vez obtener resultados parecidos a los que se alcanzarían si se realizase un estudio de toda la población. En las investigaciones llevadas por empresarios y de la medicina se usa muestreo extensivamente en recoger información sobre poblaciones.

# %% [markdown]
# Obteniendo muestras aleatorias en python.

# %%
#Muestra basada en cantidades
muestra_100 = data.sample(100)
muestra_100
# Out:
#         valores
# 5892  10.860789
# 1235  10.594296
# 7922   9.986788
# 2982  11.103281
# 5992  11.711658
# ...         ...
# 2990  11.061259
# 8896  10.640861
# 213   10.459886
# 8080   9.507795
# 637    9.317383
#
# [100 rows x 1 columns]

# %% [markdown]
# En este caso para la muestra usamos un total de 100 elementos de los 10000 datos.

# %% [markdown]
# En lugar de indicar el número de registros de la submuestra se puede utilizar el porcentaje de registros. Para ello se ha de emplear la opción frac con un valor entre 0 y 1.

# %%
#muestreo mediante porcentajes de la poblacion total
muestra_60_porciento = data.sample(frac=0.6)
muestra_60_porciento
# Out:
#         valores
# 6706  10.137135
# 4115  10.802161
# 8698   8.702642
# 5551  12.044701
# 332    9.340924
# ...         ...
# 9734  10.721067
# 4275  10.161646
# 7016  10.233393
# 9209  10.430088
# 7834   9.885262
#
# [6000 rows x 1 columns]

# %% [markdown]
# # Teorema Central del Limite

# %% [markdown]
# ![teoremacentral.jpg](attachment:teoremacentral.jpg)

# %% [markdown]
# El teorema central del límite (TCL) es una teoría estadística que establece que, dada una muestra suficientemente grande de la población, la distribución de las medias muestrales seguirá una distribución normal.

# %% [markdown]
# Para este ejemplo se calculara una probabilidad de un muestra aleatoria.

# %%
muestra = data.sample(10000)
z = (muestra['valores'].mean()-data['valores'].mean())/desviacion_tipica/np.sqrt(10000)
print(z)
# Out:
# 0.0

# %% [markdown]
# De acuerdo a la tabla la probabilidad de la muestra aleatoria con respecto a la orgina es de 0.5

# %% [markdown]
# # Contraste de Hipotesis

# %% [markdown]
# Dentro de la inferencia estadística, un contraste de hipótesis (también denominado test de hipótesis o prueba de significación) es un procedimiento para juzgar si una propiedad que se supone en una población estadística es compatible con lo observado en una muestra de dicha población. Fue iniciada por Ronald Fisher y fundamentada posteriormente por Jerzy Neyman y Karl Pearson.

# %% [markdown]
# El contraste esta dado por la siguiente formula.

# %% [markdown]
# ![hipof.jpg](attachment:hipof.jpg)

# %% [markdown]
# Para practicar un ejemplo podriamos hacer una hipotesis afirmando que la media de nuestros valores se mayor 9. Por lo tanto:
#
# H0 = 9 (hipotesis nula)
#
# H1 > 9 (hipotesis alternativa)
#
# si nuestro resultado es mayor a 1.69, debemos de descartar la hipotesis nula y tomar en cuenta la alternativa.

# %% [markdown]
# Ejemplo de codigo en python.

# %%
t = (data['valores'].mean() - 9) / (desviacion_tipica / np.sqrt(10000))
print(t)
# Out:
# 98.54180246983411

# %% [markdown]
# Como se puede ver el valor es mayor al limite (1.69) por lo tanto descartamos h0 y tomamos h1.

# %% [markdown]
# # Test de la Chi Cuadrada

# %% [markdown]
# La prueba chi-cuadrado es una de las más conocidas y utilizadas para analizar variables nominales o cualitativas, es decir, para determinar la existencia o no de independencia entre dos variables. Que dos variables sean independientes significa que no tienen relación, y que por lo tanto una no depende de la otra, ni viceversa.

# %% [markdown]
# # Corelacion entre variables

# %% [markdown]
# La Correlación es una técnica estadística usada para determinar la relación entre dos o más variables

# %%
variable1 = np.random.normal(10, 1, 1000)
variable2 = variable1 *10
data3 = pd.DataFrame(
    {
        "x":variable1.tolist(),"y":variable2.tolist()
    }
)
data3
plt.plot(data3['x'],data3['y'],"ro")

# %% [markdown]
# De acuerdo a la grafica podemos comprobar que tienen correlacion.

# %% [markdown]
# Verifiquemos la correlacion mediante el indice de correlacion.

# %%
data3.corr()
# Out:
#      x    y
# x  1.0  1.0
# y  1.0  1.0

# %% [markdown]
# Si el resultado es de 1 quiere decir que ambas variables estan fuertemente relacionadas.

# %%
plt.matshow(data3.corr())

# %% [markdown]
# Tambien podemos crear una matriz de correlacion para verificar la relacion entre una variable con otra.
